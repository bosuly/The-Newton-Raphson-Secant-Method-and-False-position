# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from typing import Callable, Optional

# ==========================================
# 1. SETUP & CONFIGURATION
# ==========================================
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# We store all 5 functions in a list of dictionaries for easy looping.
# logical_guesses helps us pick valid starting points for each specific function.
test_cases = [
    {
        "id": "A",
        "func": lambda x: x**5 + x - 1,
        "deriv": lambda x: 5*x**4 + 1,
        "formula": "x^5 + x - 1",
        "guess_nr": 0.5,       # Newton Initial Guess
        "bracket": (0, 1)      # Secant/False Position Bracket
    },
    {
        "id": "B",
        "func": lambda x: x**5 + 5*x**3 - 4*x + 1,
        "deriv": lambda x: 5*x**4 + 15*x**2 - 4,
        "formula": "x^5 + 5x^3 - 4x + 1",
        "guess_nr": 0.5,
        "bracket": (0, 1)
    },
    {
        "id": "C",
        "func": lambda x: x**5 + 2*x**4 - x - 3,
        "deriv": lambda x: 5*x**4 + 8*x**3 - 1,
        "formula": "x^5 + 2x^4 - x - 3",
        "guess_nr": 1.0,
        "bracket": (0, 2)
    },
    {
        "id": "D",
        "func": lambda x: x**5 - 10,
        "deriv": lambda x: 5*x**4,
        "formula": "x^5 - 10",
        "guess_nr": 1.5,       # x=0 would cause div by zero here!
        "bracket": (1, 2)
    },
    {
        "id": "E",
        "func": lambda x: x**5 + 2*x**2 + x - 0.5,
        "deriv": lambda x: 5*x**4 + 4*x + 1,
        "formula": "x^5 + 2x^2 + x - 0.5",
        "guess_nr": 0.5,
        "bracket": (0, 1)
    }
]

# ==========================================
# 2. ALGORITHM IMPLEMENTATIONS
# ==========================================

def newton_raphson(func, deriv, x0, tol=1e-6, max_iter=20):
    logs = []
    x_curr = x0
    
    for i in range(max_iter):
        f_val = func(x_curr)
        df_val = deriv(x_curr)
        
        if abs(df_val) < 1e-15:
            print(f"  [Error] Derivative zero at {x_curr}")
            break
            
        x_next = x_curr - (f_val / df_val)
        err = abs(x_next - x_curr)
        
        logs.append({"Iter": i+1, "x": x_curr, "f(x)": f_val, "Error": err})
        
        if err < tol:
            return x_next, pd.DataFrame(logs)
        x_curr = x_next
        
    return x_curr, pd.DataFrame(logs)

def secant_method(func, x0, x1, tol=1e-6, max_iter=20):
    logs = []
    
    for i in range(max_iter):
        f0 = func(x0)
        f1 = func(x1)
        
        if abs(f1 - f0) < 1e-15:
            print("  [Error] Division by zero in Secant")
            break
            
        x_new = x1 - f1 * (x1 - x0) / (f1 - f0)
        err = abs(x_new - x1)
        
        logs.append({"Iter": i+1, "x_prev": x0, "x_curr": x1, "Error": err})
        
        if err < tol:
            return x_new, pd.DataFrame(logs)
        x0, x1 = x1, x_new
        
    return x_new, pd.DataFrame(logs)

# ==========================================
# 3. VISUALIZATION FUNCTION
# ==========================================

def plot_function_analysis(case, root, x_range=(-2, 2)):
    x = np.linspace(x_range[0], x_range[1], 400)
    y = case["func"](x)
    
    plt.figure()
    plt.plot(x, y, label=f'f(x) = {case["formula"]}', linewidth=2, color='#2563eb')
    plt.axhline(0, color='black', linewidth=1)
    plt.axvline(0, color='black', linewidth=1)
    
    # Mark the root
    if root is not None:
        plt.plot(root, case["func"](root), 'ro', label=f'Root: {root:.5f}', zorder=5)
        
    # Optional: Tangent Line at initial guess (for Newton visual)
    x0 = case["guess_nr"]
    y0 = case["func"](x0)
    m = case["deriv"](x0)
    tan_x = np.linspace(x0-1, x0+1, 100)
    tan_y = m*(tan_x - x0) + y0
    plt.plot(tan_x, tan_y, 'g--', alpha=0.6, label=f'Tangent at guess {x0}')

    plt.title(f"Analysis: {case['formula']}", fontsize=14)
    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

# ==========================================
# 4. MAIN LOOP (PROCESS ALL TASKS)
# ==========================================

for case in test_cases:
    print(f"\n{'='*60}")
    print(f" FUNCTION {case['id']}: {case['formula']}")
    print(f"{'='*60}")
    
    # --- A. Newton-Raphson ---
    print(f"1. Newton-Raphson (Guess: {case['guess_nr']})")
    root_nr, log_nr = newton_raphson(case["func"], case["deriv"], case["guess_nr"])
    print(log_nr.to_string(index=False)) # Print clean table
    print(f"   => Final Root: {root_nr:.6f}\n")
    
    # --- B. Secant Method ---
    print(f"2. Secant Method (Bracket: {case['bracket']})")
    root_sec, log_sec = secant_method(case["func"], case["bracket"][0], case["bracket"][1])
    print(log_sec.to_string(index=False))
    print(f"   => Final Root: {root_sec:.6f}\n")
    
    # --- C. Visualization ---
    # We use the root found by Newton-Raphson for the plot marker
    plot_function_analysis(case, root_nr, x_range=(-2.5, 2.5))
# Out:
# ============================================================
#  FUNCTION A: x^5 + x - 1
# ============================================================
# 1. Newton-Raphson (Guess: 0.5)
#  Iter        x          f(x)        Error
#     1 0.500000 -4.687500e-01 3.571429e-01
#     2 0.857143  3.198072e-01 8.646066e-02
#     3 0.770682  4.256180e-02 1.539924e-02
#     4 0.755283  1.064013e-03 4.050176e-04
#     5 0.754878  7.063891e-07 2.692450e-07
#    => Final Root: 0.754878
#
# 2. Secant Method (Bracket: (0, 1))
#  Iter   x_prev   x_curr        Error
#     1 0.000000 1.000000 5.000000e-01
#     2 1.000000 0.500000 1.595745e-01
#     3 0.500000 0.659574 1.358993e-01
#     4 0.659574 0.795474 4.700155e-02
#     5 0.795474 0.748472 5.984169e-03
#     6 0.748472 0.754456 4.256765e-04
#     7 0.754456 0.754882 4.436412e-06
#     8 0.754882 0.754878 3.062333e-09
#    => Final Root: 0.754878
# ============================================================
#  FUNCTION B: x^5 + 5x^3 - 4x + 1
# ============================================================
# 1. Newton-Raphson (Guess: 0.5)
#  Iter        x          f(x)        Error
#     1 0.500000 -3.437500e-01 5.500000e+00
#     2 6.000000  8.833000e+03 1.258979e+00
#     3 4.741021  2.910158e+03 1.017787e+00
#     4 3.723233  9.596591e+02 8.238996e-01
#     5 2.899334  3.161395e+02 6.649863e-01
#     6 2.234347  1.035223e+02 5.295250e-01
#     7 1.704822  3.335644e+01 4.076179e-01
#     8 1.297204  1.039864e+01 2.937541e-01
#     9 1.003450  3.055502e+00 1.889256e-01
#    10 0.814525  8.024118e-01 9.842416e-02
#    11 0.716101  1.599881e-01 3.195405e-02
#    12 0.684146  1.439050e-02 3.496037e-03
#    13 0.680650  1.641523e-04 4.080914e-05
#    14 0.680610  2.225408e-08 5.533981e-09
#    => Final Root: 0.680610
#
# 2. Secant Method (Bracket: (0, 1))
#  Iter     x_prev     x_curr     Error
#     1   0.000000   1.000000  1.500000
#     2   1.000000  -0.500000  5.357143
#     3  -0.500000  -5.857143  5.355549
#     4  -5.857143  -0.501594  0.001594
#     5  -0.501594  -0.503188 22.430528
#     6  -0.503188 -22.933716 22.430520
#     7 -22.933716  -0.503196  0.000008
#     8  -0.503196  -0.503204 19.737144
#     9  -0.503204 -20.240349 19.737131
#    10 -20.240349  -0.503218  0.000013
#    11  -0.503218  -0.503231 19.666151
#    12  -0.503231 -20.169382 19.666137
#    13 -20.169382  -0.503245  0.000014
#    14  -0.503245  -0.503258 19.587268
#    15  -0.503258 -20.090527 19.587254
#    16 -20.090527  -0.503272  0.000014
#    17  -0.503272  -0.503286 19.507826
#    18  -0.503286 -20.011112 19.507812
#    19 -20.011112  -0.503300  0.000014
#    20  -0.503300  -0.503314 19.427785
#    => Final Root: -19.931100
# ============================================================
#  FUNCTION C: x^5 + 2x^4 - x - 3
# ============================================================
# 1. Newton-Raphson (Guess: 1.0)
#  Iter        x          f(x)        Error
#     1 1.000000 -1.000000e+00 8.333333e-02
#     2 1.083333  1.635360e-01 1.018401e-02
#     3 1.073149  2.757805e-03 1.777094e-04
#     4 1.072972  8.266279e-07 5.329880e-08
#    => Final Root: 1.072972
#
# 2. Secant Method (Bracket: (0, 2))
#  Iter     x_prev     x_curr     Error
#     1   0.000000   2.000000  1.903226
#     2   2.000000   0.096774  0.094909
#     3   0.096774   0.191683  3.284762
#     4   0.191683  -3.093079  3.393002
#     5  -3.093079   0.299924  0.115164
#     6   0.299924   0.415088  6.202401
#     7   0.415088  -5.787313  6.207289
#     8  -5.787313   0.419976  0.004894
#     9   0.419976   0.424869 14.073329
#    10   0.424869 -13.648460 14.073446
#    11 -13.648460   0.424986  0.000116
#    12   0.424986   0.425102 15.038538
#    13   0.425102 -14.613435 15.038625
#    14 -14.613435   0.425190  0.000087
#    15   0.425190   0.425277 15.114323
#    16   0.425277 -14.689046 15.114409
#    17 -14.689046   0.425363  0.000086
#    18   0.425363   0.425449 15.183926
#    19   0.425449 -14.758478 15.184010
#    20 -14.758478   0.425533  0.000084
#    => Final Root: 0.425616
# ============================================================
#  FUNCTION D: x^5 - 10
# ============================================================
# 1. Newton-Raphson (Guess: 1.5)
#  Iter        x          f(x)        Error
#     1 1.500000 -2.406250e+00 9.506173e-02
#     2 1.595062  3.249385e-01 1.003971e-02
#     3 1.585022  4.064820e-03 1.288042e-04
#     4 1.584893  6.605883e-07 2.093924e-08
#    => Final Root: 1.584893
#
# 2. Secant Method (Bracket: (1, 2))
#  Iter   x_prev   x_curr        Error
#     1 1.000000 2.000000 7.096774e-01
#     2 2.000000 1.290323 1.603765e-01
#     3 1.290323 1.450699 2.012738e-01
#     4 1.450699 1.651973 7.886390e-02
#     5 1.651973 1.573109 1.082127e-02
#     6 1.573109 1.583930 9.773222e-04
#     7 1.583930 1.584908 1.445200e-05
#     8 1.584908 1.584893 1.754922e-08
#    => Final Root: 1.584893
# ============================================================
#  FUNCTION E: x^5 + 2x^2 + x - 0.5
# ============================================================
# 1. Newton-Raphson (Guess: 0.5)
#  Iter        x     f(x)        Error
#     1 0.500000 0.531250 1.603774e-01
#     2 0.339623 0.074828 3.085681e-02
#     3 0.308766 0.002245 9.843831e-04
#     4 0.307781 0.000002 9.764331e-07
#    => Final Root: 0.307780
#
# 2. Secant Method (Bracket: (0, 1))
#  Iter   x_prev   x_curr        Error
#     1 0.000000 1.000000 8.750000e-01
#     2 1.000000 0.125000 7.824571e-02
#     3 0.125000 0.203246 1.287477e-01
#     4 0.203246 0.331993 2.689983e-02
#     5 0.331993 0.305094 2.622252e-03
#     6 0.305094 0.307716 6.486856e-05
#     7 0.307716 0.307781 1.753145e-07
#    => Final Root: 0.307780
